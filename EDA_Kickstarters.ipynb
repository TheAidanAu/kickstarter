# %% [markdown]
# write a for loop to load the zipped csv file, inspect each file in pandas first before merging them

# %%
import numpy as np
import pandas as pd

# %%
from zipfile import ZipFile
from io import BytesIO
import urllib.request as urllib2

r = urllib2.urlopen("https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2021-09-16T03_20_11_333Z.zip").read()
file = ZipFile(BytesIO(r))
salaries_csv = file.open("Kickstarter.csv","Kickstarter001.csv")
salaries = pd.read_csv(salaries_csv).head()
print (salaries)


col_headers=list(salaries.columns)
col_headers

# %%
col_headers=list(salaries.columns)
col_headers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b7783060d0dc> in <module>
# ----> 1 col_headers=list(salaries.columns)
#       2 col_headers
#
# NameError: name 'salaries' is not defined

# %%
r_last = urllib2.urlopen("https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2016-01-28T09_15_08_781Z.zip").read()
file_last = ZipFile(BytesIO(r))
salaries_csv_last = file.open("Kickstarter.csv")
salaries_last = pd.read_csv(salaries_csv_last).head()

# %%
salaries_last
# Out:
#    backers_count                                              blurb  \
# 0             45  Taking you inside and outside of prison, and a...
# 1             21  A podcast of working at a tech company in the ...
# 2            146  A live morning radio show broadcasted online e...
# 3             31  For Season 9 of the Clive Barker Podcast and n...
# 4              9  A 16 page Zine filled with articles, reviews a...
#
#                                             category  \
# 0  {"id":357,"name":"Audio","analytics_name":"Aud...
# 1  {"id":357,"name":"Audio","analytics_name":"Aud...
# 2  {"id":357,"name":"Audio","analytics_name":"Aud...
# 3  {"id":357,"name":"Audio","analytics_name":"Aud...
# 4  {"id":357,"name":"Audio","analytics_name":"Aud...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                      4506      US        the United States  1577743896
# 1                       322      US        the United States  1573666016
# ...

# %%
col_names_last=list(salaries_last.columns)
col_names_last
# Out:
# ['backers_count',
#  'blurb',
#  'category',
#  'converted_pledged_amount',
#  'country',
#  'country_displayable_name',
#  'created_at',
#  'creator',
#  'currency',
#  'currency_symbol',
#  'currency_trailing_code',
#  'current_currency',
#  'deadline',
#  'disable_communication',
#  'friends',
#  'fx_rate',
#  'goal',
#  'id',
#  'is_backing',
#  'is_starrable',
#  'is_starred',
#  'launched_at',
#  'location',
#  'name',
#  'permissions',
#  'photo',
#  'pledged',
#  'profile',
#  'slug',
#  'source_url',
#  'spotlight',
#  'staff_pick',
#  'state',
#  'state_changed_at',
#  'static_usd_rate',
#  'urls',
#  'usd_exchange_rate',
#  'usd_pledged',
#  'usd_type']

# %%
salaries_last.created_at.value_counts()
# Out:
# 1577743896    1
# 1573666016    1
# 1574060612    1
# 1574880653    1
# 1571141508    1
# Name: created_at, dtype: int64

# %%
#col_headers
#col_names_last
[item in col_headers for item in col_names_last]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
r_last = urllib2.urlopen("https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2016-01-28T09_15_08_781Z.zip").read()
file_last = ZipFile(BytesIO(r))
salaries_csv_last = file.open("Kickstarter.csv")
salaries_last = pd.read_csv(salaries_csv_last).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-65345dd0ccd5> in <module>
# ----> 1 r_last = urllib2.urlopen("https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2016-01-28T09_15_08_781Z.zip").read()
#       2 file_last = ZipFile(BytesIO(r))
#       3 salaries_csv_last = file.open("Kickstarter.csv")
#       4 salaries_last = pd.read_csv(salaries_csv_last).head()
#
# NameError: name 'urllib2' is not defined

# %%
from zipfile import ZipFile
import io
from urllib.request import urlopen
import pandas as pd

r = urlopen("https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2021-09-16T03_20_11_333Z.zip").read()
file = ZipFile(io.BytesIO(r))
data_df = pd.read_csv(file.open("Kickstarter001.csv"), encoding='latin1')
data_df_noflags = pd.read_csv(file.open("Kickstarter002.csv"), encoding='latin1')
data_df_flags = pd.read_csv(file.open("Kickstarter003.csv"), encoding='latin1')

# %%
data_df
# Out:
#       backers_count                                              blurb  \
# 0               314  A warrior queen with divine power has been flu...
# 1                16  Postcard with RuinDynamics cut scene. RuinDyna...
# 2                68  The third and final volume in the psychedelic ...
# 3               142  A new Minneapolis tea house combining traditio...
# 4               237  100% Damascus performance oriented knife set, ...
# ...             ...                                                ...
# 3653              1                    Hot sauce, bbq sauce, seasoning
# 3654            796  Learning programming the fun way: Become a Pyt...
# 3655            211  Let TiM fill out your Startwork Packet for you...
# 3656             71  Everything you need to know to develop top-qua...
# 3657             20  Novel writing has evolved! \nTechnology provid...
#
#                                                category  \
# 0     {"id":252,"name":"Graphic Novels","analytics_n...
# ...

# %%
import requests
import pandas as pd
from zipfile import ZipFile
from io import BytesIO

r_1 = requests.get("https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2016-01-28T09_15_08_781Z.zip")
files = ZipFile(BytesIO(r_1.content))
df_one=pd.read_csv(files.open("Kickstarter001.csv"))
df_two=pd.read_csv(files.open("Kickstarter002.csv"))

# %%
df_one
# Out:
#               id                                              photo  \
# 0     1892945715  {"small":"https://ksr-ugc.imgix.net/projects/2...
# 1     1538400326  {"small":"https://ksr-ugc.imgix.net/projects/4...
# 2      566893531  {"small":"https://ksr-ugc.imgix.net/projects/4...
# 3      327777939  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4     2082897896  {"small":"https://ksr-ugc.imgix.net/projects/8...
# ...          ...                                                ...
# 4622   539379183  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4623  1914939072  {"small":"https://ksr-ugc.imgix.net/projects/9...
# 4624   121113220  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4625  1443985097  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4626  1076799672  {"small":"https://ksr-ugc.imgix.net/projects/8...
#
#                                                    name  \
# 0          Preying Man-tis: An Exploration of Fertility
# ...

# %%
df_two
# Out:
#               id                                              photo  \
# 0     1575165604  {"small":"https://ksr-ugc.imgix.net/projects/2...
# 1      687876438  {"small":"https://ksr-ugc.imgix.net/projects/5...
# 2      691008875  {"small":"https://ksr-ugc.imgix.net/projects/6...
# 3     1002304874  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4      569706893  {"small":"https://ksr-ugc.imgix.net/projects/1...
# ...          ...                                                ...
# 4641  1849564490  {"small":"https://ksr-ugc.imgix.net/projects/7...
# 4642  1609002349  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4643   420226486  {"small":"https://ksr-ugc.imgix.net/projects/9...
# 4644   718194613  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4645   777748343  {"small":"https://ksr-ugc.imgix.net/projects/3...
#
#                                                    name  \
# 0     Walkabout Woods - Burning Man 2011 Art Install...
# ...

# %%
from zipfile import ZipFile
from io import BytesIO
import urllib.request as urllib2
import pandas as pd

# get the zip file
url = urllib2.urlopen("https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2016-01-28T09_15_08_781Z.zip").read()
files = ZipFile(BytesIO(url))

# get the file names into a list; you could use this list for different things 
# and to get certain files etc.
listOfFilesNames = sorted(files.namelist())
listOfFilesNames

# open a file from the list; in this case position 23.  This part could be a loop etc. 
# and if 'specificFileName' do something different etc.
myCSV = files.open(listOfFilesNames[0])

# create the dataframe
df = pd.read_csv(myCSV)

# check the output
print(df)
# Out:
#               id                                              photo  \
# 0      857125548  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 1     1038659700  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 2     1238331911  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 3      189217262  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4     1260075071  {"small":"https://ksr-ugc.imgix.net/projects/1...
# ...          ...                                                ...
# 4639   815131323  {"small":"https://ksr-ugc.imgix.net/projects/4...
# 4640   387555544  {"small":"https://ksr-ugc.imgix.net/projects/9...
# 4641   381137522  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4642   592609443  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4643  1346758630  {"small":"https://ksr-ugc.imgix.net/projects/8...
#
#                                                    name  \
# 0                                                 Remix
# ...

# %%
myCSV2 = files.open(listOfFilesNames[1])

# %%
df2 = pd.read_csv(myCSV2)
df2
# Out:
#               id                                              photo  \
# 0     1892945715  {"small":"https://ksr-ugc.imgix.net/projects/2...
# 1     1538400326  {"small":"https://ksr-ugc.imgix.net/projects/4...
# 2      566893531  {"small":"https://ksr-ugc.imgix.net/projects/4...
# 3      327777939  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4     2082897896  {"small":"https://ksr-ugc.imgix.net/projects/8...
# ...          ...                                                ...
# 4622   539379183  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4623  1914939072  {"small":"https://ksr-ugc.imgix.net/projects/9...
# 4624   121113220  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4625  1443985097  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4626  1076799672  {"small":"https://ksr-ugc.imgix.net/projects/8...
#
#                                                    name  \
# 0          Preying Man-tis: An Exploration of Fertility
# ...

# %%
listOfFilesNames
# Out:
# ['Kickstarter.csv',
#  'Kickstarter001.csv',
#  'Kickstarter002.csv',
#  'Kickstarter003.csv',
#  'Kickstarter004.csv',
#  'Kickstarter005.csv',
#  'Kickstarter006.csv',
#  'Kickstarter007.csv',
#  'Kickstarter008.csv',
#  'Kickstarter009.csv',
#  'Kickstarter010.csv',
#  'Kickstarter011.csv',
#  'Kickstarter012.csv',
#  'Kickstarter013.csv',
#  'Kickstarter014.csv',
#  'Kickstarter015.csv',
#  'Kickstarter016.csv',
#  'Kickstarter017.csv',
#  'Kickstarter018.csv',
#  'Kickstarter019.csv',
#  'Kickstarter020.csv',
#  'Kickstarter021.csv',
#  'Kickstarter022.csv',
#  'Kickstarter023.csv',
#  'Kickstarter024.csv',
#  'Kickstarter025.csv',
#  'Kickstarter026.csv',
#  'Kickstarter027.csv',
#  'Kickstarter028.csv',
#  'Kickstarter029.csv',
#  'Kickstarter030.csv',
#  'Kickstarter031.csv']

# %%
from urllib.request import urlopen
import zipfile, io

url = 'https://s3.amazonaws.com/weruns/forfun/Kickstarter/Kickstarter_2016-01-28T09_15_08_781Z.zip'

archive = zipfile.ZipFile(io.BytesIO(urlopen(url).read())) # Takes some time

csv_path = 'Kickstarter001.csv'
csv_path2 = 'Kickstarter002.csv' # The desired csv file in the archive

df11 = pd.read_csv(io.BytesIO(archive.read(csv_path)))
df22 = pd.read_csv(io.BytesIO(archive.read(csv_path2)))# Takes some time

# %%
df11
# Out:
#               id                                              photo  \
# 0     1892945715  {"small":"https://ksr-ugc.imgix.net/projects/2...
# 1     1538400326  {"small":"https://ksr-ugc.imgix.net/projects/4...
# 2      566893531  {"small":"https://ksr-ugc.imgix.net/projects/4...
# 3      327777939  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4     2082897896  {"small":"https://ksr-ugc.imgix.net/projects/8...
# ...          ...                                                ...
# 4622   539379183  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4623  1914939072  {"small":"https://ksr-ugc.imgix.net/projects/9...
# 4624   121113220  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4625  1443985097  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4626  1076799672  {"small":"https://ksr-ugc.imgix.net/projects/8...
#
#                                                    name  \
# 0          Preying Man-tis: An Exploration of Fertility
# ...

# %%
df22
# Out:
#               id                                              photo  \
# 0     1575165604  {"small":"https://ksr-ugc.imgix.net/projects/2...
# 1      687876438  {"small":"https://ksr-ugc.imgix.net/projects/5...
# 2      691008875  {"small":"https://ksr-ugc.imgix.net/projects/6...
# 3     1002304874  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4      569706893  {"small":"https://ksr-ugc.imgix.net/projects/1...
# ...          ...                                                ...
# 4641  1849564490  {"small":"https://ksr-ugc.imgix.net/projects/7...
# 4642  1609002349  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4643   420226486  {"small":"https://ksr-ugc.imgix.net/projects/9...
# 4644   718194613  {"small":"https://ksr-ugc.imgix.net/projects/1...
# 4645   777748343  {"small":"https://ksr-ugc.imgix.net/projects/3...
#
#                                                    name  \
# 0     Walkabout Woods - Burning Man 2011 Art Install...
# ...

# %%
import pandas as pd

df_desktop = pd.read_csv (r'/Users/aidanau/Desktop/folder/ks-projects-201801.csv')
print (df_desktop)
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
import pandas as pd
df_com_test = pd.read_csv (r'/Users/aidanau/Desktop/combine/Kickstarter.csv')
print (df_com_test)
# Out:
#       backers_count                                              blurb  \
# 0                45  Taking you inside and outside of prison, and a...
# 1                21  A podcast of working at a tech company in the ...
# 2               146  A live morning radio show broadcasted online e...
# 3                31  For Season 9 of the Clive Barker Podcast and n...
# 4                 9  A 16 page Zine filled with articles, reviews a...
# ...             ...                                                ...
# 3658             24  Issues 1 & 2 of a Sci-fi/steampunk fantasy gra...
# 3659            115  Eloisa Aquino's illustrated life stories of qu...
# 3660             47  After an experiment goes horrifically wrong, D...
# 3661            716  A hardcover of The Nicodemus Job, the greatest...
# 3662            217  Everyone's favourite supernatural sailor retur...
#
#                                                category  \
# 0     {"id":357,"name":"Audio","analytics_name":"Aud...
# ...

# %%
df_com = pd.read_csv (r'/Users/aidanau/Desktop/combine/combined.csv')
print (df_com)
# Out:
#       backers_count                                              blurb  \
# 0                45  Taking you inside and outside of prison, and a...
# 1                21  A podcast of working at a tech company in the ...
# 2               146  A live morning radio show broadcasted online e...
# 3                31  For Season 9 of the Clive Barker Podcast and n...
# 4                 9  A 16 page Zine filled with articles, reviews a...
# ...             ...                                                ...
# 29727            27  コロナとの日々で出会った、あなたの「忘れたくない本」とその思い出を、デジタルメッセージや1冊...
# 29728             1  A published all-in-one guide and self journal ...
# 29729             1  My master plan to end POVERTY, HOMELESSNESS, M...
# 29730             6  The Citadel Magazine is seeking to fund a year...
# 29731             1  For centuries the Waorani tribe pass their kno...
#
#                                                 category  \
# ...

# %%
df_com.shape
# Out:
# (29732, 39)

# %%
import pandas as pd
chunksize = 100000
tfr = pd.read_csv(r'/Users/aidanau/Desktop/combine/One/2021-05-13_Kickstarter022.csv', chunksize=chunksize, iterator=True)
dfk = pd.concat(tfr, ignore_index=True)
print(dfk)
# Out:
#       backers_count                                              blurb  \
# 0                 4  On GoHobby, All Of The Best Thrills Are Only A...
# 1                13  Self-publishing a young adult novel set in Ger...
# 2                 1  My project gives the reader a guide on how to ...
# 3                13  I'm building an actual, newsprint-printed-news...
# 4                 3  A poetry book about unrequited love, themes of...
# ...             ...                                                ...
# 3661             17  Presenting personal and community stories in a...
# 3662            154  Help fund an acoustic tour that will bring me ...
# 3663            248  mēk, a trio consisting of members from Alien A...
# 3664             30        A publication about the places of Bob Dylan
# 3665             29  『RISIKO（リジコ）』は、ドイツのアンダーグラウンド／オルタナティヴな音楽シーンの「今」...
#
#                                                category  \
# 0     {"id":332,"name":"Apps","analytics_name":"Apps...
# ...
